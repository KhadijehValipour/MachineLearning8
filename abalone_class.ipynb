# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.linalg import inv
from sklearn .model_selection import train_test_split
from lls import LinearLeastSquare

# %%
data = pd.read_csv("abalone.csv")
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data["Sex"].replace(["F","M","I"],[0,1,2],inplace=True)

# %%
data.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.503697 -0.516450 -0.477850     -0.501511
# Length         -0.503697  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.516450  0.986812  1.000000  0.833684      0.925452
# Height         -0.477850  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.501511  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.459731  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.505693  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.499103  0.897706  0.905330  0.817338      0.955355
# Rings          -0.401445  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.459731       -0.505693     -0.499103 -0.401445
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
data.drop(["Sex"] , axis = 1 , inplace = True)
data.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
plt.scatter(data['Length'], data['Height'] ,color='blue' , label = "data" )
plt.xlabel("Length")
plt.ylabel("Height")
plt.legend()
plt.grid()
plt.show()

# %%
X =np.array( data[["Length"]])
Y = np.array(data[['Height']])

print(X.shape)
print(Y.shape)
# Out:
# (4177, 1)
# (4177, 1)

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (3132, 1)
# (3132, 1)
# (1045, 1)
# (1045, 1)

# %%
lls = LinearLeastSquare()

# %%
lls.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 lls.fit(X_train,Y_train)
#
# File c:\Users\KhadijehValipour\Desktop\FILE_D\PYLEARN7\45\lls.py:10, in LinearLeastSquare.fit(self, X_train, Y_train)
#       8 def fit(self , X_train , Y_train):
#       9     # train
# ---> 10     self.W = inv(X_train.T @ X_train) @ X_train.T @ Y_train
#
# TypeError: 'module' object is not callable

# %%
Y_pred = lls.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 Y_pred = lls.predict(X_test)
#
# File c:\Users\KhadijehValipour\Desktop\FILE_D\PYLEARN7\45\lls.py:13, in LinearLeastSquare.predict(self, X_test)
#      12 def predict(self , X_test) :
# ---> 13     Y_pred = X_test @ self.W
#      14     return Y_pred
#
# AttributeError: 'LinearLeastSquare' object has no attribute 'W'
